# %%
import numpy as np
from scipy.optimize import approx_fprime
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Задание 1
# Придумайте функции со следующими свойствами (в a) b) c) область определения X любая, какая вам удобна, главное - функция с нужными свойствами):
#
# a) бесконечное количество локальных экстремумов
#
# b) 2 локальных экстремума
#
# с) 3 локальных экстремума
#
# d*) область определения функции - 1 точка

# %%
x = [x for x in range (500)]
y = [math.sin(y) for y in range (500)]

plt.plot(x, y)

# %%
def func_b(x):
    return (x**5 - x*5)

x = np.linspace(-2, 2, 7000)
y = [func_b(y) for y in x]

plt.plot(x,y)

# %%
def func_c(x):
    return (x**5 - x*5)**2

x = np.linspace(-2, 2, 7000)
y = [func_c(y) for y in x]

plt.plot(x,y)

# %% [markdown]
# $y = sqrt(-x^2)$

# %% [markdown]
# ## Задание 2
# Посчитайте 1-ую и 2-ую производные функции (на бумажке):
#
# $f(x) = sin^2(2x+1)$

# %% [markdown]
# $f'(x) = 2sin(2x + 1) * (sin(2x+1))' = 2sin(2x + 1) * cos(2x+1) * (2x+1)' = 2sin(2x + 1) * cos(2x+1) * 2 = 2sin(4x+2)$
#
# $f''(x) = 2cos(4x+2) * (4x+2)' = 8cos(4x+2)$

# %% [markdown]
# ## Задание 3:
# Посчитайте частные производные функции в точкe (на бумажке или в LaTeX и на numpy):
#
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$ в точке $(1,2)$
#
# $ΔF/Δx= 4 * 1 * 2^3 + 2^2 - 1/-1^2 = 35$
#
# $ΔF/Δy= 6 * 1^2 * 2^2 + 2 * 1 * 2 = 28$

# %% [markdown]
# ## Задание 4:
# Градиентный спуск своими руками

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

x = np.array([100, 200])
lr = 0.1


for i in range(100):
    # Calculate gradient
    eps = np.sqrt(np.finfo(float).eps)
    grad = approx_fprime(x, f, [eps, eps])# Your code here (функция для вычисления градиента есть в лекционном ноутбуке)
    # Update x with gradient
    x1 = x - lr * grad # Your code here (смотри слайд презентации про градиентный спуск)
    if f(x1) <= f(x):
        x = x1
    else:
        break

print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
# Out:
# Минимум достигается в:  [1.29197811e-08 3.32901401e-08]
# Значение функции в минимуме:  1.2751541739575636e-15

# %%
from scipy.optimize import minimize
res = minimize(f, x, method='nelder-mead', options={'xtol': 1e-6, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
